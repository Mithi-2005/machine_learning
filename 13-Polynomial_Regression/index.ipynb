# %% [markdown]
# #### Polynomial Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=6*np.random.rand(100,1)-3
y=0.5 * x**2 + 1.5*x + 2 + np.random.randn(100,1) ## Quadratic Equation : y=0.5*x^2+1.5x+2+Outliers

# %%
plt.scatter(x,y,color='g')
plt.xlabel("X Dataset")
plt.ylabel("Y Dataset")
# Out:
# Text(0, 0.5, 'Y Dataset')

# %%
import re
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ##### Lets check linear regression first

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(x_test)

# %%
from sklearn.metrics import r2_score
score=r2_score(y_pred=y_pred,y_true=y_test)
print(score)
# Out:
# 0.7396036878605456

# %%
plt.plot(x_train,regression.predict(x_train))
plt.scatter(x_train,y_train)

# %% [markdown]
# #### Now lets apply polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures

poly=PolynomialFeatures(degree=2,include_bias=True)

# %%
x_train_poly=poly.fit_transform(x_train)
x_test_poly=poly.transform(x_test)

# %%
x_train_poly
# Out:
# array([[ 1.00000000e+00,  2.23927046e-01,  5.01433220e-02],
#        [ 1.00000000e+00, -6.48123583e-01,  4.20064179e-01],
#        [ 1.00000000e+00, -2.16401796e+00,  4.68297373e+00],
#        [ 1.00000000e+00, -2.20789663e+00,  4.87480751e+00],
#        [ 1.00000000e+00, -1.88214111e+00,  3.54245516e+00],
#        [ 1.00000000e+00,  8.94159735e-01,  7.99521633e-01],
#        [ 1.00000000e+00,  1.52357738e+00,  2.32128802e+00],
#        [ 1.00000000e+00,  2.60946088e+00,  6.80928608e+00],
#        [ 1.00000000e+00,  1.94750088e+00,  3.79275966e+00],
#        [ 1.00000000e+00, -1.65722051e+00,  2.74637982e+00],
#        [ 1.00000000e+00,  8.21783641e-01,  6.75328352e-01],
#        [ 1.00000000e+00, -6.69276820e-01,  4.47931462e-01],
#        [ 1.00000000e+00, -2.20390132e+00,  4.85718103e+00],
#        [ 1.00000000e+00,  2.83182522e+00,  8.01923410e+00],
#        [ 1.00000000e+00, -9.10708811e-01,  8.29390539e-01],
#        [ 1.00000000e+00, -2.85206027e+00,  8.13424778e+00],
#        [ 1.00000000e+00,  7.60686870e-01,  5.78644515e-01],
#        [ 1.00000000e+00, -6.44588407e-01,  4.15494214e-01],
#        [ 1.00000000e+00,  8.07334385e-01,  6.51788810e-01],
#        [ 1.00000000e+00, -2.88070602e+00,  8.29846718e+00],
#        [ 1.00000000e+00, -2.12539511e+00,  4.51730437e+00],
#        [ 1.00000000e+00,  3.82968321e-01,  1.46664735e-01],
#        [ 1.00000000e+00,  2.58632664e-02,  6.68908548e-04],
#        [ 1.00000000e+00, -1.29315749e+00,  1.67225629e+00],
#        [ 1.00000000e+00,  4.35633234e-01,  1.89776314e-01],
#        [ 1.00000000e+00, -3.36987648e-01,  1.13560675e-01],
#        [ 1.00000000e+00, -1.26035184e+00,  1.58848677e+00],
#        [ 1.00000000e+00,  1.46707487e+00,  2.15230867e+00],
#        [ 1.00000000e+00,  8.36912678e-01,  7.00422831e-01],
#        [ 1.00000000e+00, -2.31093023e+00,  5.34039852e+00],
#        [ 1.00000000e+00,  1.72898556e+00,  2.98939108e+00],
#        [ 1.00000000e+00,  2.95716350e+00,  8.74481594e+00],
#        [ 1.00000000e+00, -2.65489394e-01,  7.04846184e-02],
#        [ 1.00000000e+00,  1.42138542e+00,  2.02033653e+00],
#        [ 1.00000000e+00, -2.97927489e-01,  8.87607886e-02],
#        [ 1.00000000e+00,  1.46364062e+00,  2.14224385e+00],
#        [ 1.00000000e+00,  1.02819701e+00,  1.05718909e+00],
#        [ 1.00000000e+00,  8.98988193e-01,  8.08179772e-01],
#        [ 1.00000000e+00, -1.56808716e+00,  2.45889734e+00],
#        [ 1.00000000e+00, -2.10622429e-01,  4.43618076e-02],
#        [ 1.00000000e+00, -1.72654900e+00,  2.98097145e+00],
#        [ 1.00000000e+00, -2.51120282e+00,  6.30613963e+00],
#        [ 1.00000000e+00, -2.40661767e+00,  5.79180861e+00],
#        [ 1.00000000e+00,  1.31929881e+00,  1.74054935e+00],
#        [ 1.00000000e+00, -1.71615910e+00,  2.94520204e+00],
#        [ 1.00000000e+00, -2.70865207e+00,  7.33679603e+00],
#        [ 1.00000000e+00, -2.36137386e-01,  5.57608649e-02],
#        [ 1.00000000e+00,  2.43956346e+00,  5.95146989e+00],
#        [ 1.00000000e+00,  1.91901364e+00,  3.68261335e+00],
#        [ 1.00000000e+00,  2.82619652e-02,  7.98738678e-04],
#        [ 1.00000000e+00, -2.72545812e+00,  7.42812194e+00],
#        [ 1.00000000e+00,  1.88503301e+00,  3.55334944e+00],
#        [ 1.00000000e+00,  4.19861823e-01,  1.76283951e-01],
#        [ 1.00000000e+00, -2.05163124e+00,  4.20919075e+00],
#        [ 1.00000000e+00,  1.64057740e+00,  2.69149419e+00],
#        [ 1.00000000e+00,  2.67733227e+00,  7.16810807e+00],
#        [ 1.00000000e+00, -1.88393652e+00,  3.54921681e+00],
#        [ 1.00000000e+00, -1.07651609e+00,  1.15888688e+00],
#        [ 1.00000000e+00,  7.91483655e-01,  6.26446376e-01],
#        [ 1.00000000e+00,  9.90977416e-01,  9.82036238e-01],
#        [ 1.00000000e+00, -2.14334743e+00,  4.59393820e+00],
#        [ 1.00000000e+00, -2.92712347e+00,  8.56805183e+00],
#        [ 1.00000000e+00,  1.29150107e+00,  1.66797502e+00],
#        [ 1.00000000e+00,  7.82446432e-01,  6.12222418e-01],
#        [ 1.00000000e+00, -2.80028230e+00,  7.84158095e+00],
#        [ 1.00000000e+00,  5.90612947e-01,  3.48823653e-01],
#        [ 1.00000000e+00, -5.86016674e-01,  3.43415542e-01],
#        [ 1.00000000e+00, -1.06883635e+00,  1.14241115e+00],
#        [ 1.00000000e+00, -1.31828925e+00,  1.73788655e+00],
#        [ 1.00000000e+00,  1.32964460e+00,  1.76795476e+00],
#        [ 1.00000000e+00,  1.35454345e+00,  1.83478797e+00],
#        [ 1.00000000e+00, -1.57444116e+00,  2.47886496e+00],
#        [ 1.00000000e+00,  9.27522217e-01,  8.60297463e-01],
#        [ 1.00000000e+00,  2.63863077e+00,  6.96237235e+00],
#        [ 1.00000000e+00, -1.06438479e+00,  1.13291498e+00],
#        [ 1.00000000e+00, -1.94390096e+00,  3.77875096e+00],
#        [ 1.00000000e+00,  1.75631796e+00,  3.08465277e+00],
#        [ 1.00000000e+00, -1.66454868e+00,  2.77072229e+00],
#        [ 1.00000000e+00,  1.51925077e+00,  2.30812290e+00],
#        [ 1.00000000e+00,  1.71572900e+00,  2.94372601e+00]])

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(x_train_poly,y_train)
y_pred=regression.predict(x_test_poly)
score=r2_score(y_test,y_pred)
print(score)
# Out:
# 0.9087893735405168

# %%
from sklearn.pipeline import Pipeline
